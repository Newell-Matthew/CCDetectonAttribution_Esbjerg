# %%
import xarray as xr
import glob
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import pandas as pd

from matplotlib.patches import Rectangle
from scipy.stats import pearsonr

# %%
#Select study domain
lat_min, lat_max = 5.0, 5.5
lon_min, lon_max = -5.6, -4.5

# %%
validation_dataset = xr.open_dataset('O:\\Man\\Public\\sharing-4270-CERM\\MATNEW\\Era5-Land\\Hourly_Data\\Precipitation\\era5_land_1950_2024_tp_daily_update_DK_regridCLIMEX.nc')
validation_dataset = validation_dataset.rename({"tp": "pr"})
validation_dataset = validation_dataset *1000
validation_dataset = validation_dataset.sel(rlat=slice(lat_min, lat_max), rlon=slice(lon_min, lon_max))

# %%
all_pr_model_files = glob.glob("O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\**\\*.nc")

# %%
all_pr_model_files
# Out:
# ['O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kct\\pr_EUR-11_CCCma-CanESM2_historical_r5-r6i1p1_OURANOS-CRCM5_kct_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbf\\pr_EUR-11_CCCma-CanESM2_historical_r1-r6i1p1_OURANOS-CRCM5_kbf_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcs\\pr_EUR-11_CCCma-CanESM2_historical_r5-r5i1p1_OURANOS-CRCM5_kcs_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcu\\pr_EUR-11_CCCma-CanESM2_historical_r5-r7i1p1_OURANOS-CRCM5_kcu_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcj\\pr_EUR-11_CCCma-CanESM2_historical_r4-r6i1p1_OURANOS-CRCM5_kcj_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kby\\pr_EUR-11_CCCma-CanESM2_historical_r3-r5i1p1_OURANOS-CRCM5_kby_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbk\\pr_EUR-11_CCCma-CanESM2_historical_r2-r1i1p1_OURANOS-CRCM5_kbk_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbq\\pr_EUR-11_CCCma-CanESM2_historical_r2-r7i1p1_OURANOS-CRCM5_kbq_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbu\\pr_EUR-11_CCCma-CanESM2_historical_r3-r1i1p1_OURANOS-CRCM5_kbu_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcg\\pr_EUR-11_CCCma-CanESM2_historical_r4-r3i1p1_OURANOS-CRCM5_kcg_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbw\\pr_EUR-11_CCCma-CanESM2_historical_r3-r3i1p1_OURANOS-CRCM5_kbw_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbp\\pr_EUR-11_CCCma-CanESM2_historical_r2-r6i1p1_OURANOS-CRCM5_kbp_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcf\\pr_EUR-11_CCCma-CanESM2_historical_r4-r2i1p1_OURANOS-CRCM5_kcf_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbs\\pr_EUR-11_CCCma-CanESM2_historical_r2-r9i1p1_OURANOS-CRCM5_kbs_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kci\\pr_EUR-11_CCCma-CanESM2_historical_r4-r5i1p1_OURANOS-CRCM5_kci_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbc\\pr_EUR-11_CCCma-CanESM2_historical_r1-r3i1p1_OURANOS-CRCM5_kbc_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbg\\pr_EUR-11_CCCma-CanESM2_historical_r1-r7i1p1_OURANOS-CRCM5_kbg_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcn\\pr_EUR-11_CCCma-CanESM2_historical_r4-r10i1p1_OURANOS-CRCM5_kcn_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcr\\pr_EUR-11_CCCma-CanESM2_historical_r5-r4i1p1_OURANOS-CRCM5_kcr_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbz\\pr_EUR-11_CCCma-CanESM2_historical_r3-r6i1p1_OURANOS-CRCM5_kbz_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kch\\pr_EUR-11_CCCma-CanESM2_historical_r4-r4i1p1_OURANOS-CRCM5_kch_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbh\\pr_EUR-11_CCCma-CanESM2_historical_r1-r8i1p1_OURANOS-CRCM5_kbh_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kce\\pr_EUR-11_CCCma-CanESM2_historical_r4-r1i1p1_OURANOS-CRCM5_kce_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcl\\pr_EUR-11_CCCma-CanESM2_historical_r4-r8i1p1_OURANOS-CRCM5_kcl_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbr\\pr_EUR-11_CCCma-CanESM2_historical_r2-r8i1p1_OURANOS-CRCM5_kbr_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbm\\pr_EUR-11_CCCma-CanESM2_historical_r2-r3i1p1_OURANOS-CRCM5_kbm_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbo\\pr_EUR-11_CCCma-CanESM2_historical_r2-r5i1p1_OURANOS-CRCM5_kbo_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbe\\pr_EUR-11_CCCma-CanESM2_historical_r1-r5i1p1_OURANOS-CRCM5_kbe_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcw\\pr_EUR-11_CCCma-CanESM2_historical_r5-r9i1p1_OURANOS-CRCM5_kcw_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcb\\pr_EUR-11_CCCma-CanESM2_historical_r3-r8i1p1_OURANOS-CRCM5_kcb_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kca\\pr_EUR-11_CCCma-CanESM2_historical_r3-r7i1p1_OURANOS-CRCM5_kca_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcm\\pr_EUR-11_CCCma-CanESM2_historical_r4-r9i1p1_OURANOS-CRCM5_kcm_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcx\\pr_EUR-11_CCCma-CanESM2_historical_r5-r10i1p1_OURANOS-CRCM5_kcx_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbi\\pr_EUR-11_CCCma-CanESM2_historical_r1-r9i1p1_OURANOS-CRCM5_kbi_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbv\\pr_EUR-11_CCCma-CanESM2_historical_r3-r2i1p1_OURANOS-CRCM5_kbv_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kba\\pr_EUR-11_CCCma-CanESM2_historical_r1-r1i1p1_OURANOS-CRCM5_kba_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbx\\pr_EUR-11_CCCma-CanESM2_historical_r3-r4i1p1_OURANOS-CRCM5_kbx_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbj\\pr_EUR-11_CCCma-CanESM2_historical_r1-r10i1p1_OURANOS-CRCM5_kbj_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcp\\pr_EUR-11_CCCma-CanESM2_historical_r5-r2i1p1_OURANOS-CRCM5_kcp_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcd\\pr_EUR-11_CCCma-CanESM2_historical_r3-r10i1p1_OURANOS-CRCM5_kcd_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbt\\pr_EUR-11_CCCma-CanESM2_historical_r2-r10i1p1_OURANOS-CRCM5_kbt_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbl\\pr_EUR-11_CCCma-CanESM2_historical_r2-r2i1p1_OURANOS-CRCM5_kbl_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbn\\pr_EUR-11_CCCma-CanESM2_historical_r2-r4i1p1_OURANOS-CRCM5_kbn_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbb\\pr_EUR-11_CCCma-CanESM2_historical_r1-r2i1p1_OURANOS-CRCM5_kbb_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kbd\\pr_EUR-11_CCCma-CanESM2_historical_r1-r4i1p1_OURANOS-CRCM5_kbd_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcv\\pr_EUR-11_CCCma-CanESM2_historical_r5-r8i1p1_OURANOS-CRCM5_kcv_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcq\\pr_EUR-11_CCCma-CanESM2_historical_r5-r3i1p1_OURANOS-CRCM5_kcq_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kco\\pr_EUR-11_CCCma-CanESM2_historical_r5-r1i1p1_OURANOS-CRCM5_kco_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kcc\\pr_EUR-11_CCCma-CanESM2_historical_r3-r9i1p1_OURANOS-CRCM5_kcc_day_1951-2100_BC_Esbjerg.nc',
#  'O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\Climex DK Domain\\pr_daily_bc_V2\\kck\\pr_EUR-11_CCCma-CanESM2_historical_r4-r7i1p1_OURANOS-CRCM5_kck_day_1951-2100_BC_Esbjerg.nc']

# %%
# Open multiple files and concatenate along 'time' dimension
validation_ds = validation_dataset

# Select data from 2011 to 2024 
validation_ds_selected = validation_ds.sel(
time=(
    (validation_ds["time"].dt.year >= 2011) &  
    (validation_ds["time"].dt.year <= 2024)  
),
drop=True  # Remove any missing data in the time range
)

val_annual_precipitation_sum = validation_ds_selected.resample(time="YE").mean()
val_annual_precipitation_mean = val_annual_precipitation_sum.mean(dim="time")
val_annual_precipitation_spatial_mean = val_annual_precipitation_mean.mean(dim=["rlat", "rlon"])

val_monthly_precipitation_sum = validation_ds_selected.resample(time="ME").mean()
val_monthly_precipitation_spatial_mean = val_monthly_precipitation_sum.groupby("time.month").mean(dim="time").mean(dim=["rlat", "rlon"])

# %%
val_annual_precipitation_mean.pr.plot()

# %%
model_outputs = {}

# %%
# %%time

# Open multiple files and concatenate along 'time' dimension
pr_ds = xr.open_mfdataset(all_pr_model_files, combine="nested", concat_dim="realization")
print("Finished opening CLIMEX dataset.")

pr_ds = pr_ds.sel(rlat=slice(lat_min, lat_max), rlon=slice(lon_min, lon_max))

# Select data 
pr_ds = pr_ds.sel(
time=(
    (pr_ds["time"].dt.year >= 2011) &  
    (pr_ds["time"].dt.year <= 2024)  
),
drop=True  # Remove any missing data in the time range
)

#Indicator I
model_annual_precipitation_sum = pr_ds.resample(time="YE").mean()
model_annual_precipitation_mean = model_annual_precipitation_sum.mean(dim="time").mean(dim='realization')
model_annual_precipitation_spatial_mean = model_annual_precipitation_mean.mean(dim=["rlat", "rlon"])
model_annual_rel_difference = ((model_annual_precipitation_spatial_mean - val_annual_precipitation_spatial_mean)/val_annual_precipitation_spatial_mean).pr.values.item()*100

#Indicator II
model_monthly_precipitation_sum = pr_ds.resample(time="ME").mean().mean(dim='realization')
model_monthly_precipitation_spatial_mean = model_monthly_precipitation_sum.groupby("time.month").mean(dim="time").mean(dim=["rlat", "rlon"])
model_monthly_difference = 100 - np.abs((((np.abs(model_monthly_precipitation_spatial_mean - val_monthly_precipitation_spatial_mean).sum()/12)-val_annual_precipitation_spatial_mean)/val_annual_precipitation_spatial_mean).pr.values.item()*100)

#Indicator III
#Calculate standard deviation ratio of monthly values
s_model = model_monthly_precipitation_spatial_mean.std()
s_val = val_monthly_precipitation_spatial_mean.std()
s = s_val / s_model
s = s.pr.values

#Calculate correlation of monthly values
r, _= pearsonr(model_monthly_precipitation_spatial_mean.pr.values.flatten(), 
               val_monthly_precipitation_spatial_mean.pr.values.flatten())

#Calculate KGE (Indicator III)
KGE = 1-((r-1)**2 + (s-1)**2)

mask = ~np.isnan(model_annual_precipitation_mean.pr.values.flatten())

#Indicator IV
correlation, _ = pearsonr(model_annual_precipitation_mean.pr.values.flatten()[mask], 
                          val_annual_precipitation_mean.pr.values.flatten()[mask]) 

# Store the spatial mean in the dictionary
model_outputs = {
    'Indicator I': model_annual_rel_difference,
    'Indicator II': model_monthly_difference,
    'Indicator III' : KGE,
    'Indicator IV' : correlation
}
# Out:
# Finished opening CLIMEX dataset.
# CPU times: total: 1min
# Wall time: 1min 31s

# %%
model_outputs
# Out:
# {'Indicator I': -5.716094002127647,
#  'Indicator II': 10.624021291732788,
#  'Indicator III': 0.7621292206139663,
#  'Indicator IV': 0.9962613476966325}

# %%
#Save model_outputs to pandas dataframe
model_outputs_df = pd.DataFrame.from_dict(model_outputs, orient='index')

# %%
model_outputs_df
# Out:
#                        0
# Indicator I    -5.716094
# Indicator II   10.624021
# Indicator III   0.762129
# Indicator IV    0.996261

# %% [markdown]
# ## Check shapefile projection

# %%
shp = gpd.read_file('O:\\Man\\Public\\sharing-4270-CERM\\VLYMI\\CLIMEX\\gadm36_DNK_0.shp')
shp = shp.to_crs("epsg:25832")
shp = shp.to_crs("+proj=ob_tran +o_proj=longlat +o_lon_p =0 +o_lat_p= 39.25 +lon_0 = 18 +to_meter=0.01745329")

# %%
var = pr_ds.pr.sel(time = "1989-01-02").mean(dim='realization')

# Get lat/lon
rlon = validation_ds["rlon"]
rlat = validation_ds["rlat"]

# %%
# --- Quick Plot ---
fig, ax = plt.subplots(figsize=(8, 6))

# Plot NetCDF data (without projection)
plt.pcolormesh(rlon, rlat, var.squeeze(), cmap="viridis", shading="auto")

# Overlay Shapefile (without transformation)
shp.boundary.plot(ax=ax, color="black", linewidth=0.5)

# Draw Bounding Box (Red Rectangle)
ax.add_patch(Rectangle((-5.6, 5.0), -4.5 - -5.6, 5.5 - 5.0,
                       linewidth=2, edgecolor='red', facecolor='none'))

# Set title
plt.title("Shapefile vs. NetCDF Quick Check")

plt.show()
